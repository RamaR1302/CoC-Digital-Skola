# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4540/915460594.py in <module>
# ----> 1 from matplotlib import pyplot as plt
#       2 import seaborn as sns
#       3 import numpy as np
#       4 import pandas as pd
#       5 import scipy as scp
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
df = pd.read_csv('https://raw.githubusercontent.com/vaksakalli/datasets/master/diamonds.csv')
df
# Out:
#        carat        cut color clarity  depth  table     x     y     z  price
# 0       0.23      Ideal     E     SI2   61.5   55.0  3.95  3.98  2.43    326
# 1       0.21    Premium     E     SI1   59.8   61.0  3.89  3.84  2.31    326
# 2       0.23       Good     E     VS1   56.9   65.0  4.05  4.07  2.31    327
# 3       0.29    Premium     I     VS2   62.4   58.0  4.20  4.23  2.63    334
# 4       0.31       Good     J     SI2   63.3   58.0  4.34  4.35  2.75    335
# ...      ...        ...   ...     ...    ...    ...   ...   ...   ...    ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0  5.75  5.76  3.50   2757
# 53936   0.72       Good     D     SI1   63.1   55.0  5.69  5.75  3.61   2757
# 53937   0.70  Very Good     D     SI1   62.8   60.0  5.66  5.68  3.56   2757
# 53938   0.86    Premium     H     SI2   61.0   58.0  6.15  6.12  3.74   2757
# 53939   0.75      Ideal     D     SI2   62.2   55.0  5.83  5.87  3.64   2757
#
# [53940 rows x 10 columns]

# %% [markdown]
# # Soal 1: Scatter Plot

# %% [markdown]
# Buatlah scatterplot menggunakan Seaborn dari data df di atas, variasikan menggunakan palette yang telah disediakan sehingga didapatkan output sesuai expected.

# %%
fig, ax = plt.subplots(figsize=(13, 13))
palette="ch:r=-.2,d=.3_r"
sns.despine(fig, left=True, bottom=True)
ranking = ("I1","SI2","SI1","VS2","VS1","VVS2","VVS1","IF")
data= sns.load_dataset("diamonds")
sns.scatterplot(x = 'carat', y = 'price', size='depth',
                palette=palette, hue ='clarity',
                hue_order = ranking, sizes=(1,8),
                linewidth = 0, ax=ax, data = data)
plt.show()

# %% [markdown]
# Expected Output:
#
# ![alt text](https://drive.google.com/uc?id=1OyzNnrnkJ7TL8DIyh_2O97WuzesyLL7W)

# %% [markdown]
# # Soal 2: Facet Grid

# %% [markdown]
# Gunakan fungsi hexbin berikut untuk diterapkan pada mapping dari facetgridnya sehingga dihasilkan output sesuai expected.
#
# ```
# def hexbin(x, y, color, **kwargs):
#     cmap = sns.light_palette(color, as_cmap=True)
#     plt.hexbin(x, y, gridsize=15, cmap=cmap, **kwargs)
# ```

# %%
def hexbin(x, y, color, **kwargs):
    cmap = sns.light_palette(color, as_cmap=True)
    plt.hexbin(x, y, gridsize=15, cmap=cmap, **kwargs)
    
#your code here
with sns.axes_style('darkgrid'):
  g= sns.FacetGrid(df, hue='cut', col='cut', height=4)
  g.map(hexbin,'carat','price', extent=[0.0, 3.0, 0.0, 20000]);

# %% [markdown]
# Expected Output:
#
# ![alt text](https://drive.google.com/uc?id=1ZG6Uu0R_8mPAjpwublowrdUM6Hd1OXkI)

# %% [markdown]
# # Soal 3: Pair Plot

# %% [markdown]
# Ambil 300 data secara acak dari df, kemudian buat pair plotnya dari 300 data tersebut untuk kolom carat, depth, table, dan price sehingga dihasilkan output sesuai expected.

# %%
df1 = df.sample(n=300, random_state=123)

#your code here
sns.pairplot(df1, hue='cut', vars=['carat','depth','table','price'], markers=['*','o','s','D','X'], corner=True)

# %% [markdown]
# Expected Output:
#
# ![alt text](https://drive.google.com/uc?id=1N3guRLAn5sIhfzzKFdvf1cZpmtEc-cw9)

# %% [markdown]
# # Soal 4: Joint Plot

# %% [markdown]
# Gunakan data yang sama dengan soal 3 untuk menghasilkan dua visualisasi joint plot antara carat dan price nya sesuai expected output.

# %%
from scipy.stats import pearsonr
with sns.axes_style("white"):
  g1 = sns.jointplot(
      x= "carat",
      y="price",
      data=df,
      kind="kde"
      )
with sns.axes_style("ticks"):
  g2 = sns.jointplot(
      "carat",
      "price",
      data= df,
      kind='reg',
      stat_func=pearsonr)
  
  g2.ax_marg_x.set_xlim(0.0 , 2.5)
  g2.ax_marg_y.set_ylim(0, 21250)
  plt.show()

# %%
data = sns.load_dataset("diamonds")
sns.jointplot(x = "carat", y = "price",
              kind = "kde", data = data)
plt.show()

# %%
with sns.axes_style("white"):
  g = sns.jointplot("carat", "price", data=df, kind="kde")
with sns.axes_style("ticks"):
  g2 = sns.jointplot("carat", "price",data=df, kind='reg', stat_func=pearsonr)
  g2.ax_marg_x.set_xlim(0.0, 2.5)
  g2.ax_marg_y.set_ylim(0, 21250)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-101-7c36f40a3599> in <module>()
#       2   g = sns.jointplot("carat", "price", data=df, kind="kde")
#       3 with sns.axes_style("ticks"):
# ----> 4   g2 = sns.jointplot("carat", "price",data=df, kind='reg', stat_func=pearsonr)
#       5   g2.ax_marg_x.set_xlim(0.0, 2.5)
#       6   g2.ax_marg_y.set_ylim(0, 21250)
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py in jointplot(x, y, data, kind, color, height, ratio, space, dropna, xlim, ylim, marginal_ticks, joint_kws, marginal_kws, hue, palette, hue_order, hue_norm, **kwargs)
#    2200
#    2201         joint_kws.setdefault("color", color)
# -> 2202         grid.plot_joint(regplot, **joint_kws)
#    2203
#    2204     elif kind.startswith("resid"):
#
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py in plot_joint(self, func, **kwargs)
#    1732
#    1733         if str(func.__module__).startswith("seaborn"):
# -> 1734             func(x=self.x, y=self.y, **kwargs)
#    1735         else:
#    1736             func(self.x, self.y, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# TypeError: regplot() got an unexpected keyword argument 'stat_func'

# %% [markdown]
# Expected Output 1:
#
# ![alt text](https://drive.google.com/uc?id=1xX5Jq38-rr_oFD-eDRbBYCBA24Nmw2C5)
#
# Expected Output 2:
#
# ![alt text](https://drive.google.com/uc?id=1QXY89CXRe1BzU0k7OBrr2fTn8WwIhWHo)
